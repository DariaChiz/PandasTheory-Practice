# %%
import pandas as pd
print(pd.__name__)
# Out:
# pandas

# %% [markdown]
# # pd.Series()

# %%
countries = pd.Series(data = ['Англия', 'Канада', 'США', 
                              'Россия', 'Украина', 'Беларусь', 
                              'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries  = pd.Series(['Англия', 'Канада', 'США', 
                              'Россия', 'Украина', 'Беларусь', 
                              'Казахстан'])
display(countries)
# Out:
# 0       Англия
# 1       Канада
# 2          США
# 3       Россия
# 4      Украина
# 5     Беларусь
# 6    Казахстан
# dtype: object

# %%
# Способ2, создаем из словаря, ключами являются будущие метки,
# а значениями - будущие значения Series
# использование name также возможно

countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US': 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
    )
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %% [markdown]
# # Доступ к данным: loc или iloc

# %%
print(countries.loc['US'])
# Out:
# США

# %%
print(countries[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
# Out:
# Казахстан

# %%
print(countries.iloc[1:4])
# Out:
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %% [markdown]
# # DATAFRAME КАК СТРУКТУРА ДАННЫХ

# %%
# Способ №1

import pandas as pd

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 
                'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 
                   45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191,
               603628, 207600, 2724902]
})
display (countries_df)

# так как мы не задали метки (индексы) DataFrame, 
# они были сгенерированы автоматически
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 
                'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 
                   45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191,
               603628, 207600, 2724902]
})
countries_df.index = ['UK', 'CA', 'US', 'RU', 
                      'UA', 'BY', 'KZ']
display (countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
# Способ №2

countries_df = pd.DataFrame(
    data = [['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns = ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
# AXIS В DATAFRAME

# считаем среднее по строкам(axis=0) в каждом столбце

countries_df[['population', 'square']].mean(axis=0)
# Out:
# population    9.070000e+01
# square        5.800860e+06
# dtype: float64

# %%
# считаем среднее по столбцам (axis=1)

countries_df[['population', 'square']].mean(axis=1)
# Out:
# UK      66726.145
# CA    4992354.025
# US    4913476.140
# RU    8562668.620
# UA     301836.750
# BY     103804.750
# KZ    1362459.520
# dtype: float64

# %%
# Доступ к столбцу
# Использование такого способа возможно только тогда, 
# когда имя столбца указано без пробелов

countries_df.population
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df['population']
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
type(countries_df.population)
# Out:
# pandas.core.series.Series

# %%
countries_df.loc['UK', 'square']
# Out:
# 133396

# %%
countries_df.loc['RU', ['population', 'square']]
# Out:
# population      146.24
# square        17125191
# Name: RU, dtype: object

# %%
countries_df.loc[['UA', 'BY', 'KZ'],
                 ['population', 'square']]
# Out:
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
countries_df.iloc[4:8, 1:3]
# Out:
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
# сохраним наш DataFrame с информацией о странах в csv-файл countries.csv и 
# положим файл в папку data. 
# При этом укажем, что разделителем в нашем файле будет являться символ ';', 
# а также то, что нам не нужен дополнительный столбец с индексами строк:

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 
                'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 
                   45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 
               603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';')
display(countries_data)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0  \
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize
# ...

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S  \
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_data.loc[15, ['Price']]
# Out:
# Price    1310000.0
# Name: 15, dtype: object

# %%
melb_data.loc[90, "Date"]
# Out:
# '10/09/2016'

# %%
melb_data.loc[3521,'Landsize']/melb_data.loc[1690, 'Landsize']
# Out:
# 2.7857142857142856

# %%
melb_data.tail(7)
# Out:
#        index         Suburb        Address  Rooms Type      Price Method
# 13573  13573       Werribee    5 Nuragi Ct      4    h   635000.0      S  \
# 13574  13574    Westmeadows     9 Black St      3    h   582000.0      S
# 13575  13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown    83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  ...  Car  Landsize  BuildingArea
# 13573  hockingstuart  26/08/2017      14.7  ...  1.0     662.0         172.0  \
# 13574            Red  26/08/2017      16.5  ...  2.0     256.0         126.0
# 13575          Barry  26/08/2017      16.7  ...  2.0     652.0         126.0
# ...

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0  \
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
melb_data.shape
# Out:
# (13580, 23)

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea', 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
# В нашем наборе данных представлены объекты, удалённые 
# от центра города на расстояние до 48 километров

# В нашей таблице представлены участки, на которых отсутствует само здание (его площадь равна 0), 
# то есть владельцы продавали участок земли без строений на нём

# Большая часть объектов (75%) имеет площадь здания до 130 квадратных метров, 
# однако в нашей таблице есть настоящий дворец (судя по его размерам) с площадью в 44 515 квадратных метров

# Диапазон цен на недвижимость в Мельбурне варьируется 
# от 85 тысяч до 9 миллионов австралийских долларов

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date
# count       13580             13580  13580  13580   13580       13580  \
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
# Наибольшее количество проданных объектов (359) 
# находилось в пригороде Reservoir

# Самый популярный тип дома — h (дом, вилла, коттедж)

# В наших данных нам известно о 268 различных риэлторских компаниях,
# однако самой главной «акулой» в этом бизнесе является компания Nelson 
# — они продали 1 565 различных домов

# В нашей таблице содержится информация за 58 дней, 
# при этом наибольшее число продаж (473) пришлось на 27 мая 2017 года

# %%
# ПОЛУЧЕНИЕ ЧАСТОТЫ УНИКАЛЬНЫХ ЗНАЧЕНИЙ В СТОЛБЦЕ

melb_data['Regionname'].value_counts()
# Out:
# Regionname
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: count, dtype: int64

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Regionname
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: proportion, dtype: float64

# %%
melb_data['Coordinates'].info
# Out:
# <bound method Series.info of 0          -37.7996, 144.9984
# 1          -37.8079, 144.9934
# 2          -37.8093, 144.9944
# 3          -37.7969, 144.9969
# 4          -37.8072, 144.9941
#                  ...
# 13575    -37.90562, 145.16761
# 13576    -37.85927, 144.87904
# 13577    -37.85274, 144.88738
# 13578    -37.85908, 144.89299
# 13579    -37.81188, 144.88449
# Name: Coordinates, Length: 13580, dtype: object>

# %%
melb_data['CouncilArea'].info()
print (13580-12211)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 13580 entries, 0 to 13579
# Series name: CouncilArea
# Non-Null Count  Dtype
# --------------  -----
# 12211 non-null  object
# dtypes: object(1)
# memory usage: 106.2+ KB
# 1369

# %%
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000  \
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000  \
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
import pandas as pd
melb_data['Type'].info
# Out:
# <bound method Series.info of 0        h
# 1        h
# 2        h
# 3        h
# 4        h
#         ..
# 13575    h
# 13576    h
# 13577    h
# 13578    h
# 13579    h
# Name: Type, Length: 13580, dtype: object>

# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S  \
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_data['Type'].value_counts(normalize=True)
# Out:
# Type
# h    0.695803
# u    0.222165
# t    0.082032
# Name: proportion, dtype: float64

# %%
# Вычислим среднюю цену на объекты недвижимости

print(melb_data['Price'].mean())
# Out:
# 1075684.079455081

# %%
# Найдем максимальное количество парковочных мест

print(melb_data['Car'].max())
# Out:
# 10.0

# %%
# Риэлторская ставка для всех компаний 
# за продажу недвижимости составляет 12%. 
# Найдём общую прибыльность риэлторского бизнеса в Мельбурне. 
# Результат округлим до сотых

rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real etstate agencies:', round(income,2))
# Out:
# Total income of real etstate agencies: 1752934775.88

# %%
# Найдём, насколько медианная площадь территории 
# отличается от её среднего значения. 
# Вычислим модуль разницы между медианой и 
# средним и разделим результат на среднее, 
# чтобы получить отклонение в долях

landsize_median = melb_data['Landsize'].median()
landsize_mean = melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# Out:
# 0.21205713983546193

# %%
# В результате получаем долю отклонения медианы от среднего значения. 
# Умножив результат на 100, получим его в процентах. 
# Отклонение медианы от среднего значения на 21% 
# является довольно большим, и это повод задуматься над тем, 
# чтобы исследовать признак на наличие аномалий.

# %%
# Вычислим, какое число комнат чаще всего представлено на рынке недвижимости

print(melb_data['Rooms'].mode())
# Out:
# 0    3
# Name: Rooms, dtype: int64

# %%
melb_data['Regionname'].mode()
# Out:
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
print(melb_data['Propertycount'].max())
# Out:
# 21650.0

# %%
print(melb_data["Distance"].std())
# Out:
# 5.868724943071711

# %%
medianBA = melb_data['BuildingArea'].median()
meanBA = melb_data['BuildingArea'].mean()
print(abs((medianBA - meanBA)/meanBA)*100)
# Out:
# 9.764079662364534

# %%
melb_data['Bedroom'].mode()
# Out:
# 0    3.0
# Name: Bedroom, dtype: float64

# %%
# ФИЛЬТРАЦИЯ ДАННЫХ

mask = melb_data['Price'] > 2000000
display(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool

# %%
display(melb_data[mask].head())
# Out:
#     index       Suburb               Address  Rooms Type      Price Method
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI  \
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea
# 80    Buxton   4/03/2017       3.3  ...  0.0     211.0         198.0  \
# 85  Marshall   7/05/2016       3.3  ...  1.0     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...  1.0     199.0         107.0
# 92    Cayzer  10/12/2016       3.3  ...  1.0     177.0         181.0
# 93      Greg  10/12/2016       3.3  ...  1.0     237.0         126.0
#
#     YearBuilt   CouncilArea  Lattitude  Longtitude             Regionname
# ...

# %%
melb_data[melb_data['Price'] > 2000000]
# Out:
#        index          Suburb               Address  Rooms Type      Price
# 80        80     Albert Park  112 Beaconsfield Pde      3    h  2850000.0  \
# 85        85     Albert Park     104 Richardson St      4    h  2300000.0
# 88        88     Albert Park        29 Faussett St      2    h  2120000.0
# 92        92     Albert Park           2 Dundas Pl      3    h  2615000.0
# 93        93     Albert Park          23 Finlay St      5    h  2100000.0
# ...      ...             ...                   ...    ...  ...        ...
# 13521  13521  Port Melbourne          44 Garton St      4    t  2455000.0
# 13523  13523         Prahran        69 Greville St      4    h  2668000.0
# 13553  13553    Surrey Hills          20 Albert Cr      4    h  2720000.0
# 13555  13555    Surrey Hills              3 Oak St      4    h  3100000.0
# 13578  13578    Williamstown          96 Verdon St      4    h  2500000.0
#
#       Method   SellerG        Date  Distance  ...  Car  Landsize
# ...

# %%
melb_data[melb_data['Rooms'] == 3].shape[0]
# Out:
# 5881

# %%
# Найдём число трёхкомнатных домов 
# с ценой менее 300 тысяч

melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 3

# %%
# Дома с ценой менее 300 тысяч, 
# у которых либо число комнат равно 3 
# либо площадь домов более 100 квадратных метров

melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 68

# %%
# Найдём максимальное количество комнат в таунхаусах.
# Так как в результате фильтрации получается DataFrame,
# то обратимся к нему по столбцу Rooms 
# и найдём максимальное значение

melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# 5

# %%
# Найдём медианную площадь здания у объектов, 
# чья цена выше средней. 
# Для того чтобы оградить наш код от нагромождений, 
# предварительно создадим переменную со средней ценой

mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# 126.0

# %%
melb_data[melb_data['Bathroom'] == 0].shape[0]
# Out:
# 34

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]
# Out:
# 5

# %%
melb_data[melb_data['BuildingArea'] == 0]['Price'].min()
# Out:
# 412500.0

# %%
melb_data[(melb_data['Price']<1e6) & ((melb_data['Rooms']>5) | (melb_data['YearBuilt'] > 2015))]['Price'].mean()
# Out:
# 769238.6363636364

# %%
melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object

# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970  \
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970  \
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0  \
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname
# ...

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
# MeanRoomsSquare - соответствует средней площади одной комнаты для каждого объекта
# разделим площадь здания на полученное ранее общее количество комнат

melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
# AreaRatio, коэффициент соотношения площади здания (BuildingArea)
# и площади участка (Landsize)

diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
import pandas as pd 
melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_df = melb_data.copy()
display(melb_df['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int32
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# MonthSale
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: proportion, dtype: float64

# %%
# Работа с интервалами
# Вычислим сколько дней прошло с 1 января 2016 года до момента продажи объекта

delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01')
display(delta_days)
# Out:
# 0       337 days
# 1        34 days
# 2       428 days
# 3       428 days
# 4       155 days
#           ...
# 13575   603 days
# 13576   603 days
# 13577   603 days
# 13578   603 days
# 13579   603 days
# Name: Date, Length: 13580, dtype: timedelta64[ns]

# %%
# Превратим количество дней из формата интервала 
# в формат целого числа дней,
# воспользуемся аксессором dt 
# для формата timedelta 
# и извлечем из него атрибут days

display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int32

# %%
# Создадим  признак возраста объекта недвижимотси в годах на момент продажи
# Выделим из столбца продажи год и вычтем из него год постройки здания
# Результат оформим в виде нового столбца AgeBuilding

melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
# Поскольку AgeBuilding дублирует информацию YearBuilt
# Оставим возраст здания, так как данный признак является более наглядным
melb_df = melb_df.drop('YearBuilt', axis=1)

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
display(melb_df['WeekdaySale'])
weekend_count = melb_df[(melb_df['WeekdaySale'] == 5) | (melb_df['WeekdaySale'] == 6)].shape[0]
print(weekend_count)
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int32
# 12822

# %%
# Создание и преобразование столбцов с помощью функций
# Вычислим количество уникальных значений в столбце с помощью метода nunique()

print(melb_df['Address'].nunique())
display (melb_df['Address'])
print(melb_df['Address'].loc[177])
print(melb_df['Address'].loc[1812])
print(melb_df['Address'].loc[9001])
# Out:
# 13378
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object
# 2/119 Railway St N
# 9/400 Dandenong Rd
# 172 Danks St

# %%
# Адрес строится следующим образом: 
# сначала указывается номер дома и корпус, 
# после указывается название улицы, 
# а в конце — подтип улицы, 
# но в некоторых случаях 
# к подтипу добавляется географическая отметка 
# (N — север, S — юг и т. д.), она нам не нужна .
# Для того чтобы выделить подтип улицы, 
# на которой находится объект,
# можно использовать следующую функцию:

# %%
# На вход данной функции поступает строка с адресом.
def get_street_type(address):
# Создаём список географических пометок exclude_list.    
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
    
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: Address, Length: 13580, dtype: object

# %%
#  Сколько уникальных значений в типах улицы
print(street_types.nunique())
# Out:
# 56

# %%
# рассмотрим частоту каждого подтипа улицы
display(street_types.value_counts())
# Out:
# Address
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            321
# Gr            311
# Pde           211
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            53
# Tce            47
# Wy             40
# Avenue         40
# Cct            25
# Hwy            24
# Parade         15
# Boulevard      13
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Gdns            4
# Grn             4
# Fairway         4
# Mews            4
# Crossway        3
# Righi           3
# Victoria        2
# Ridge           2
# Crofts          2
# Esp             2
# Glade           1
# Gra             1
# Ave             1
# Woodland        1
# Outlook         1
# Hts             1
# Highway         1
# Athol           1
# Summit          1
# Grand           1
# Res             1
# Nook            1
# Eyrie           1
# Dell            1
# ...

# %%
# применим  метод уменьшения количества уникальных категорий — 
# выделим n подтипов, которые встречаются чаще всего, 
# а остальные обозначим как 'other'

# %%
popular_stypes = street_types.value_counts().nlargest(10).index
print (popular_stypes)
# Out:
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object', name='Address')

# %%
# введём lambda-функцию, которая будет проверять, 
# есть ли строка x в этом перечне, 
# и, если это так, lambda-функция будет возвращать x, 
# в противном случае она будет возвращать строку 'other'

# Наконец, применим такую функцию к Series street_types, полученной ранее, 
# а результат определим в новый столбец таблицы StreetType

melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(melb_df['StreetType'])
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 13575       Cr
# 13576       Dr
# 13577       St
# 13578       St
# 13579       St
# Name: StreetType, Length: 13580, dtype: object

# %%
print(melb_df['StreetType'].nunique())
# Out:
# 11

# %%
melb_df = melb_df.drop('Address', axis=1)

# %%
melb_df['WeekdaySale']
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int32

# %%
def get_weekend(weekday):
    weekends = [5, 6]
    if weekday in weekends:
        return 1
    return 0

# %%
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
display(melb_df['Weekend'])
print (round(melb_df[melb_df['Weekend'] == 1]['Price'].mean(), 2))
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 13575    1
# 13576    1
# 13577    1
# 13578    1
# 13579    1
# Name: Weekend, Length: 13580, dtype: int64
# 1081198.64

# %%
popular_sellers = melb_df["SellerG"].value_counts().nlargest(49).index
print (popular_sellers)
# Out:
# Index(['Nelson', 'Jellis', 'hockingstuart', 'Barry', 'Ray', 'Marshall',
#        'Buxton', 'Biggin', 'Brad', 'Fletchers', 'Woodards', 'Jas', 'Greg',
#        'McGrath', 'Sweeney', 'Noel', 'Miles', 'RT', 'Gary', 'Harcourts',
#        'Hodges', 'YPA', 'Stockdale', 'Village', 'Kay', 'Raine', 'Williams',
#        'Love', 'Douglas', 'Chisholm', 'RW', 'Rendina', 'HAR', 'O'Brien', 'C21',
#        'Collins', 'Cayzer', 'Eview', 'Purplebricks', 'Philip', 'Buckingham',
#        'Bells', 'Thomson', 'Nick', 'Alexkarbon', 'McDonald', 'Burnham',
#        'Moonee', 'LITTLE'],
#       dtype='object', name='SellerG')

# %%
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_sellers else 'other')
display(melb_df['SellerG'])
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %%
b = melb_df[melb_df['SellerG'] == 'other']['Price'].min()

# %%
a = melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min()
display(a)
# Out:
# 170000.0

# %%
print(round(a/b, 1))
# Out:
# 1.3
